# %%
import joblib
import pandas as pd

# %%
model = joblib.load("../models/house_price_model.pkl")

# %%
sample = pd.DataFrame([{
    "Area": 2000,
    "Bedrooms": 3,
    "Bathrooms": 3,
    "Stories": 2,
    "Parking": 2
}])

model.predict(sample)
# Out:
# array([9166664.53704295])
